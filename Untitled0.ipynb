# %%
import numpy as np

# %%
actual_error = abs(np.exp(1)-(2+1/2+1/6))
print(actual_error)
# Out:
# 0.05161516179237857

# %%
print(np.exp(1)/24)
# Out:
# 0.11326174285246021

# %%
# Logarithm
real_val=np.log(1.2)
approx_val = (0.2-(0.2**2)/2+(0.2**3)/3-(0.2**4)/4)
actual_err = abs(real_val-approx_val)
print('real val: ', real_val)
print('approx val: ', approx_val)
print('real err: ',actual_err)
# Out:
# real val:  0.1823215567939546
# approx val:  0.18226666666666666
# real err:  5.489012728793208e-05

# %%
(1/5)*(0.2**5)
# Out:
# 6.400000000000002e-05
